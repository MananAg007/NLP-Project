# %%
print("hello")
# !export CUDA_VISIBLE_DEVICES=0,1,2,3
# Out:
# hello

# %%
# !pip3 install transformers
# helper for question to sql metadata data
import json
import os
import string
import unicodedata
import transformers

pretrained_weights = {
    ("bert", "base"): "bert-base-uncased",
    ("bert", "large"): "bert-large-uncased-whole-word-masking",
    ("roberta", "base"): "roberta-base",
    ("roberta", "large"): "roberta-large",
    ("albert", "xlarge"): "albert-xlarge-v2"
}

def create_base_model(config):
    weights_name = pretrained_weights[(config["base_class"], config["base_name"])]
    if config["base_class"] == "bert":
        return transformers.BertModel.from_pretrained(weights_name)
    elif config["base_class"] == "roberta":
        return transformers.RobertaModel.from_pretrained(weights_name)
    elif config["base_class"] == "albert":
        return transformers.AlbertModel.from_pretrained(weights_name)
    else:
        raise Exception("base_class {0} not supported".format(config["base_class"]))

def create_tokenizer(config):
    weights_name = pretrained_weights[(config["base_class"], config["base_name"])]
    if config["base_class"] == "bert":
        return transformers.BertTokenizer.from_pretrained(weights_name)
    elif config["base_class"] == "roberta":
        return transformers.RobertaTokenizer.from_pretrained(weights_name)
    elif config["base_class"] == "albert":
        return transformers.AlbertTokenizer.from_pretrained(weights_name)
    else:
        raise Exception("base_class {0} not supported".format(config["base_class"]))

def read_conf(conf_path):
    config = {}
    for line in open(conf_path, encoding="utf8"):
        if line.strip() == "" or line[0] == "#":
             continue
        fields = line.strip().split("\t")
        config[fields[0]] = fields[1]
    config["train_data_path"] =  os.path.abspath(config["train_data_path"])
    config["dev_data_path"] =  os.path.abspath(config["dev_data_path"])

    return config

def read_jsonl(jsonl):
    for line in open(jsonl, encoding="utf8"):
        sample = json.loads(line.rstrip())
        yield sample

def is_whitespace(c):
    if c == " " or c == "\t" or c == "\n" or c == "\r":
        return True
    cat = unicodedata.category(c)
    if cat == "Zs":
        return True
    return False

def is_punctuation(c):
  """Checks whether `chars` is a punctuation character."""
  cp = ord(c)
  # We treat all non-letter/number ASCII as punctuation.
  # Characters such as "^", "$", and "`" are not in the Unicode
  # Punctuation class but we treat them as punctuation anyways, for
  # consistency.
  if ((cp >= 33 and cp <= 47) or (cp >= 58 and cp <= 64) or
      (cp >= 91 and cp <= 96) or (cp >= 123 and cp <= 126)):
    return True
  cat = unicodedata.category(c)
  if cat.startswith("P") or cat.startswith("S"):
    return True
  return False

def basic_tokenize(doc):
    doc_tokens = []
    char_to_word = []
    word_to_char_start = []
    prev_is_whitespace = True
    prev_is_punc = False
    prev_is_num = False
    for pos, c in enumerate(doc):
        if is_whitespace(c):
            prev_is_whitespace = True
            prev_is_punc = False
        else:
            if prev_is_whitespace or is_punctuation(c) or prev_is_punc or (prev_is_num and not str(c).isnumeric()):
                doc_tokens.append(c)
                word_to_char_start.append(pos)
            else:
                doc_tokens[-1] += c
            prev_is_whitespace = False
            prev_is_punc = is_punctuation(c)
            prev_is_num = str(c).isnumeric()
        char_to_word.append(len(doc_tokens) - 1)

    return doc_tokens, char_to_word, word_to_char_start

class SQLExample(object):
    def __init__(self,
                 qid,
                 question,
                 table_id,
                 column_meta,
                 agg=None,
                 select=None,
                 conditions=None,
                 tokens=None,
                 char_to_word=None,
                 word_to_char_start=None,
                 value_start_end=None,
                 valid=True):
        self.qid = qid
        self.question = question
        self.table_id = table_id
        self.column_meta = column_meta
        self.agg = agg
        self.select = select
        self.conditions = conditions
        self.valid = valid
        if tokens is None:
            self.tokens, self.char_to_word, self.word_to_char_start = basic_tokenize(question)
            self.value_start_end = {}
            if conditions is not None and len(conditions) > 0:
                cur_start = None
                for cond in conditions:
                    value = cond[-1]
                    value_tokens, _, _ = basic_tokenize(value)
                    val_len = len(value_tokens)
                    for i in range(len(self.tokens)):
                        if " ".join(self.tokens[i:i+val_len]).lower() != " ".join(value_tokens).lower():
                            continue
                        s = self.word_to_char_start[i]
                        e = len(question) if i + val_len >= len(self.word_to_char_start) else self.word_to_char_start[i + val_len]
                        recovered_answer_text = question[s:e].strip()
                        if value.lower() == recovered_answer_text.lower():
                            cur_start = i
                            break

                    if cur_start is None:
                        self.valid = False
                        print([value, value_tokens, question, self.tokens])
                        # for c in question:
                        #     print((c, ord(c), unicodedata.category(c)))
                        # raise Exception()
                    else:
                        self.value_start_end[value] = (cur_start, cur_start + val_len)
        else:
            self.tokens, self.char_to_word, self.word_to_char_start, self.value_start_end = tokens, char_to_word, word_to_char_start, value_start_end

    @staticmethod
    def load_from_json(s):
        d = json.loads(s)
        keys = ["qid", "question", "table_id", "column_meta", "agg", "select", "conditions", "tokens", "char_to_word", "word_to_char_start", "value_start_end", "valid"]

        return SQLExample(*[d[k] for k in keys])

    def dump_to_json(self):
        d = {}
        d["qid"] = self.qid
        d["question"] = self.question
        d["table_id"] = self.table_id
        d["column_meta"] = self.column_meta
        d["agg"] = self.agg
        d["select"] = self.select
        d["conditions"] = self.conditions
        d["tokens"] = self.tokens
        d["char_to_word"] = self.char_to_word
        d["word_to_char_start"] = self.word_to_char_start
        d["value_start_end"] = self.value_start_end
        d["valid"] = self.valid

        return json.dumps(d)

    def output_SQ(self, return_str=True):
        agg_ops = ['NA', 'MAX', 'MIN', 'COUNT', 'SUM', 'AVG']
        cond_ops = ['=', '>', '<', 'OP']

        agg_text = agg_ops[self.agg]
        select_text = self.column_meta[self.select][0]
        cond_texts = []
        for wc, op, value_text in self.conditions:
            column_text = self.column_meta[wc][0]
            op_text = cond_ops[op]
            cond_texts.append(column_text + op_text + value_text)

        if return_str:
            sq = agg_text + ", " + select_text + ", " + " AND ".join(cond_texts)
        else:
            sq = (agg_text, select_text, set(cond_texts))
        return sq

def get_schema(tables):
    schema, headers, colTypes, naturalMap = {}, {}, {}, {}
    for table in tables:
        values = [set() for _ in range(len(table["header"]))]
        for row in table["rows"]:
            for i, value in enumerate(row):
                values[i].add(str(value).lower())
        columns = {column: values[i] for i, column in enumerate(table["header"])}

        trans = {"text": "string", "real": "real"}
        colTypes[table["id"]] = {col:trans[ty] for ty, col in zip(table["types"], table["header"])}
        schema[table["id"]] = columns
        naturalMap[table["id"]] = {col: col for col in columns}
        headers[table["id"]] = table["header"]

    return schema, headers, colTypes, naturalMap
# Out:
# Requirement already satisfied: transformers in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (4.24.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/tulip/Library/Python/3.10/lib/python/site-packages (from transformers) (2022.8.17)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (0.10.1)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (3.8.0)
# Requirement already satisfied: numpy>=1.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (1.23.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (0.13.1)
# Requirement already satisfied: tqdm>=4.27 in /Users/tulip/Library/Python/3.10/lib/python/site-packages (from transformers) (4.64.0)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->transformers) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->transformers) (1.26.12)
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.

# %%
# Featurizer
import numpy as np
import json
import os
import torch.utils.data as torch_data
from collections import defaultdict
from typing import List

stats = defaultdict(int)

class InputFeature(object):
    def __init__(self,
                 question,
                 table_id,
                 tokens,
                 word_to_char_start,
                 word_to_subword,
                 subword_to_word,
                 input_ids,
                 input_mask,
                 segment_ids):
        self.question = question
        self.table_id = table_id
        self.tokens = tokens
        self.word_to_char_start = word_to_char_start
        self.word_to_subword = word_to_subword
        self.subword_to_word = subword_to_word
        self.input_ids = input_ids
        self.input_mask = input_mask
        self.segment_ids = segment_ids

        self.columns = None
        self.agg = None
        self.select = None
        self.where_num = None
        self.where = None
        self.op = None
        self.value_start = None
        self.value_end = None

    def output_SQ(self, agg = None, sel = None, conditions = None, return_str=True):
        agg_ops = ['NA', 'MAX', 'MIN', 'COUNT', 'SUM', 'AVG']
        cond_ops = ['=', '>', '<', 'OP']

        if agg is None and sel is None and conditions is None:
            sel = np.argmax(self.select)
            agg = self.agg[sel]
            conditions = []
            for i in range(len(self.where)):
                if self.where[i] == 0:
                    continue
                conditions.append((i, self.op[i], self.value_start[i], self.value_end[i]))

        agg_text = agg_ops[agg]
        select_text = self.columns[sel]
        cond_texts = []
        for wc, op, vs, ve in conditions:
            column_text = self.columns[wc]
            op_text = cond_ops[op]
            word_start, word_end = self.subword_to_word[wc][vs], self.subword_to_word[wc][ve]
            char_start = self.word_to_char_start[word_start]
            char_end = len(self.question) if word_end + 1 >= len(self.word_to_char_start) else self.word_to_char_start[word_end + 1]
            value_span_text = self.question[char_start:char_end]
            cond_texts.append(column_text + op_text + value_span_text.rstrip())

        if return_str:
            sq = agg_text + ", " + select_text + ", " + " AND ".join(cond_texts)
        else:
            sq = (agg_text, select_text, set(cond_texts))

        return sq

class HydraFeaturizer(object):
    def __init__(self, config):
        self.config = config
        self.tokenizer = create_tokenizer(config)
        self.colType2token = {
            "string": "[unused1]",
            "real": "[unused2]"}

    def get_input_feature(self, example: SQLExample, config):
        max_total_length = int(config["max_total_length"])

        input_feature = InputFeature(
            example.question,
            example.table_id,
            [],
            example.word_to_char_start,
            [],
            [],
            [],
            [],
            []
        )

        for column, col_type, _ in example.column_meta:
            # get query tokens
            tokens = []
            word_to_subword = []
            subword_to_word = []
            for i, query_token in enumerate(example.tokens):
                if self.config["base_class"] == "roberta":
                    sub_tokens = self.tokenizer.tokenize(query_token, add_prefix_space=True)
                else:
                    sub_tokens = self.tokenizer.tokenize(query_token)
                cur_pos = len(tokens)
                if len(sub_tokens) > 0:
                    word_to_subword += [(cur_pos, cur_pos + len(sub_tokens))]
                    tokens.extend(sub_tokens)
                    subword_to_word.extend([i] * len(sub_tokens))

            if self.config["base_class"] == "roberta":
                tokenize_result = self.tokenizer.encode_plus(
                    col_type + " " + column,
                    tokens,
                    padding="max_length",
                    max_length=max_total_length,
                    truncation=True,
                    add_prefix_space=True
                )
            else:
                tokenize_result = self.tokenizer.encode_plus(
                    col_type + " " + column,
                    tokens,
                    padding="max_length",
                    max_length=max_total_length,
                    truncation_strategy="longest_first",
                    truncation=True,
                )

            input_ids = tokenize_result["input_ids"]
            input_mask = tokenize_result["attention_mask"]

            tokens = self.tokenizer.convert_ids_to_tokens(input_ids)
            column_token_length = 0
            if self.config["base_class"] == "roberta":
                for i, token_id in enumerate(input_ids):
                    if token_id == self.tokenizer.sep_token_id:
                        column_token_length = i + 2
                        break
                segment_ids = [0] * max_total_length
                for i in range(column_token_length, max_total_length):
                    if input_mask[i] == 0:
                        break
                    segment_ids[i] = 1
            else:
                for i, token_id in enumerate(input_ids):
                    if token_id == self.tokenizer.sep_token_id:
                        column_token_length = i + 1
                        break
                segment_ids = tokenize_result["token_type_ids"]

            subword_to_word = [0] * column_token_length + subword_to_word
            word_to_subword = [(pos[0]+column_token_length, pos[1]+column_token_length) for pos in word_to_subword]

            assert len(input_ids) == max_total_length
            assert len(input_mask) == max_total_length
            assert len(segment_ids) == max_total_length

            input_feature.tokens.append(tokens)
            input_feature.word_to_subword.append(word_to_subword)
            input_feature.subword_to_word.append(subword_to_word)
            input_feature.input_ids.append(input_ids)
            input_feature.input_mask.append(input_mask)
            input_feature.segment_ids.append(segment_ids)

        return input_feature

    def fill_label_feature(self, example: SQLExample, input_feature: InputFeature, config):
        max_total_length = int(config["max_total_length"])

        columns = [c[0] for c in example.column_meta]
        col_num = len(columns)
        input_feature.columns = columns

        input_feature.agg = [0] * col_num
        input_feature.agg[example.select] = example.agg
        input_feature.where_num = [len(example.conditions)] * col_num

        input_feature.select = [0] * len(columns)
        input_feature.select[example.select] = 1

        input_feature.where = [0] * len(columns)
        input_feature.op = [0] * len(columns)
        input_feature.value_start = [0] * len(columns)
        input_feature.value_end = [0] * len(columns)

        for colidx, op, _ in example.conditions:
            input_feature.where[colidx] = 1
            input_feature.op[colidx] = op
        for colidx, column_meta in enumerate(example.column_meta):
            if column_meta[-1] == None:
                continue
            se = example.value_start_end[column_meta[-1]]
            try:
                s = input_feature.word_to_subword[colidx][se[0]][0]
                input_feature.value_start[colidx] = s
                e = input_feature.word_to_subword[colidx][se[1]-1][1]-1
                input_feature.value_end[colidx] = e
                assert s < max_total_length and input_feature.input_mask[colidx][s] == 1
                assert e < max_total_length and input_feature.input_mask[colidx][e] == 1

            except:
                print("value span is out of range")
                return False

        # feature_sq = input_feature.output_SQ(return_str=False)
        # example_sq = example.output_SQ(return_str=False)
        # if feature_sq != example_sq:
        #     print(example.qid, feature_sq, example_sq)
        return True

    def load_data(self, data_paths, config, include_label=False):
        model_inputs = {k: [] for k in ["input_ids", "input_mask", "segment_ids"]}
        if include_label:
            for k in ["agg", "select", "where_num", "where", "op", "value_start", "value_end"]:
                model_inputs[k] = []

        pos = []
        input_features = []
        for data_path in data_paths.split("|"):
            cnt = 0
            for line in open(data_path, encoding="utf8"):
                example = SQLExample.load_from_json(line)
                if not example.valid and include_label == True:
                    continue

                input_feature = self.get_input_feature(example, config)
                if include_label:
                    success = self.fill_label_feature(example, input_feature, config)
                    if not success:
                        continue

                # sq = input_feature.output_SQ()
                input_features.append(input_feature)

                cur_start = len(model_inputs["input_ids"])
                cur_sample_num = len(input_feature.input_ids)
                pos.append((cur_start, cur_start + cur_sample_num))

                model_inputs["input_ids"].extend(input_feature.input_ids)
                model_inputs["input_mask"].extend(input_feature.input_mask)
                model_inputs["segment_ids"].extend(input_feature.segment_ids)
                if include_label:
                    model_inputs["agg"].extend(input_feature.agg)
                    model_inputs["select"].extend(input_feature.select)
                    model_inputs["where_num"].extend(input_feature.where_num)
                    model_inputs["where"].extend(input_feature.where)
                    model_inputs["op"].extend(input_feature.op)
                    model_inputs["value_start"].extend(input_feature.value_start)
                    model_inputs["value_end"].extend(input_feature.value_end)

                cnt += 1
                if cnt % 5000 == 0:
                    print(cnt)

                if "DEBUG" in config and cnt > 100:
                    break

        for k in model_inputs:
            model_inputs[k] = np.array(model_inputs[k], dtype=np.int64)

        return input_features, model_inputs, pos

class SQLDataset(torch_data.Dataset):
    def __init__(self, data_paths, config, featurizer, include_label=False):
        self.config = config
        self.featurizer = featurizer
        self.input_features, self.model_inputs, self.pos = self.featurizer.load_data(data_paths, config, include_label)

        print("{0} loaded. Data shapes:".format(data_paths))
        for k, v in self.model_inputs.items():
            print(k, v.shape)

    def __len__(self):
        return self.model_inputs["input_ids"].shape[0]

    def __getitem__(self, idx):
        return {k: v[idx] for k, v in self.model_inputs.items()}

# %%
# Create training data (i/o)
import argparse
import os
import sys
import shutil
import datetime
import torch.utils.data as torch_data

config = read_conf("wikisql.conf")

featurizer = HydraFeaturizer(config)
train_data = SQLDataset(config["train_data_path"], config, featurizer, True)
train_data_loader = torch_data.DataLoader(train_data, batch_size=int(config["batch_size"]), shuffle=True, pin_memory=True)

num_samples = len(train_data)
# Out:
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# /Users/tulip/Downloads/cs626/Text2SQL/colab_data/data/wikitrain.jsonl loaded. Data shapes:
# input_ids (14537, 96)
# input_mask (14537, 96)
# segment_ids (14537, 96)
# agg (14537,)
# select (14537,)
# where_num (14537,)
# where (14537,)
# op (14537,)
# value_start (14537,)
# value_end (14537,)

# %%
# base model

import numpy as np
import time
from typing import List

class BaseModel(object):
    """Define common interfaces for HydraNet models"""
    def train_on_batch(self, batch):
        raise NotImplementedError()

    def save(self, model_path, epoch):
        raise NotImplementedError()

    def load(self, model_path, epoch):
        raise NotImplementedError()

    def model_inference(self, model_inputs):
        """model prediction on processed features"""
        raise NotImplementedError()

    def dataset_inference(self, dataset: SQLDataset):
        print("model prediction start")
        start_time = time.time()
        model_outputs = self.model_inference(dataset.model_inputs)

        final_outputs = []
        for pos in dataset.pos:
            final_output = {}
            for k in model_outputs:
                final_output[k] = model_outputs[k][pos[0]:pos[1], :]
            final_outputs.append(final_output)
        print("model prediction end, time elapse: {0}".format(time.time() - start_time))
        assert len(dataset.input_features) == len(final_outputs)

        return final_outputs

    def predict_SQL(self, dataset: SQLDataset, model_outputs=None):
        if model_outputs is None:
            model_outputs = self.dataset_inference(dataset)
        sqls = []
        for input_feature, model_output in zip(dataset.input_features, model_outputs):
            agg, select, where, conditions = self.parse_output(input_feature, model_output, [])

            conditions_with_value_texts = []
            for wc in where:
                _, op, vs, ve = conditions[wc]
                word_start, word_end = input_feature.subword_to_word[wc][vs], input_feature.subword_to_word[wc][ve]
                char_start = input_feature.word_to_char_start[word_start]
                char_end = len(input_feature.question)
                if word_end + 1 < len(input_feature.word_to_char_start):
                    char_end = input_feature.word_to_char_start[word_end + 1]
                value_span_text = input_feature.question[char_start:char_end].rstrip()
                conditions_with_value_texts.append((wc, op, value_span_text))

            sqls.append((agg, select, conditions_with_value_texts))

        return sqls

    def predict_SQL_with_EG(self, engine, dataset: SQLDataset, beam_size=5, model_outputs=None):
        if model_outputs is None:
            model_outputs = self.dataset_inference(dataset)
        sqls = []
        for input_feature, model_output in zip(dataset.input_features, model_outputs):
            agg, select, where_num, conditions = self.beam_parse_output(input_feature, model_output, beam_size)
            query = {"agg": agg, "sel": select, "conds": []}
            wcs = set()
            conditions_with_value_texts = []
            for condition in conditions:
                if len(wcs) >= where_num:
                    break
                _, wc, op, vs, ve = condition
                if wc in wcs:
                    continue

                word_start, word_end = input_feature.subword_to_word[wc][vs], input_feature.subword_to_word[wc][ve]
                char_start = input_feature.word_to_char_start[word_start]
                char_end = len(input_feature.question)
                if word_end + 1 < len(input_feature.word_to_char_start):
                    char_end = input_feature.word_to_char_start[word_end + 1]
                value_span_text = input_feature.question[char_start:char_end].rstrip()

                query["conds"] = [[int(wc), int(op), value_span_text]]
                result, sql = engine.execute_dict_query(input_feature.table_id, query)
                if not result or 'ERROR: ' in result:
                    continue

                conditions_with_value_texts.append((wc, op, value_span_text))
                wcs.add(wc)

            sqls.append((agg, select, conditions_with_value_texts))

        return sqls

    def _get_where_num(self, output):
        # wn = np.argmax(output["where_num"], -1)
        # max_num = 0
        # max_cnt = np.sum(wn == 0)
        # for num in range(1, 5):
        #     cur_cnt = np.sum(wn==num)
        #     if cur_cnt > max_cnt:
        #         max_cnt = cur_cnt
        #         max_num = num
        # def sigmoid(x):
        #     return 1/(1 + np.exp(-x))
        relevant_prob = 1 - np.exp(output["column_func"][:, 2])
        where_num_scores = np.average(output["where_num"], axis=0, weights=relevant_prob)
        where_num = int(np.argmax(where_num_scores))

        return where_num

    def parse_output(self, input_feature, model_output, where_label = []):
        def get_span(i):
            offset = 0
            segment_ids = np.array(input_feature.segment_ids[i])
            for j in range(len(segment_ids)):
                if segment_ids[j] == 1:
                    offset = j
                    break

            value_start, value_end = model_output["value_start"][i, segment_ids == 1], model_output["value_end"][i, segment_ids == 1]
            l = len(value_start)
            sum_mat = value_start.reshape((l, 1)) + value_end.reshape((1, l))
            span = (0, 0)
            for cur_span, _ in sorted(np.ndenumerate(sum_mat), key=lambda x:x[1], reverse=True):
                if cur_span[1] < cur_span[0] or cur_span[0] == l - 1 or cur_span[1] == l - 1:
                    continue
                span = cur_span
                break

            return (span[0]+offset, span[1]+offset)

        select_id_prob = sorted(enumerate(model_output["column_func"][:, 0]), key=lambda x:x[1], reverse=True)
        select = select_id_prob[0][0]
        agg = np.argmax(model_output["agg"][select, :])

        where_id_prob = sorted(enumerate(model_output["column_func"][:, 1]), key=lambda x:x[1], reverse=True)
        where_num = self._get_where_num(model_output)
        where = [i for i, _ in where_id_prob[:where_num]]
        conditions = {}
        for idx in set(where + where_label):
            span = get_span(idx)
            op = np.argmax(model_output["op"][idx, :])
            conditions[idx] = (idx, op, span[0], span[1])

        return agg, select, where, conditions

    def beam_parse_output(self, input_feature, model_output, beam_size=5):
        def get_span(i):
            offset = 0
            segment_ids = np.array(input_feature.segment_ids[i])
            for j in range(len(segment_ids)):
                if segment_ids[j] == 1:
                    offset = j
                    break

            value_start, value_end = model_output["value_start"][i, segment_ids == 1], model_output["value_end"][i, segment_ids == 1]
            l = len(value_start)
            sum_mat = value_start.reshape((l, 1)) + value_end.reshape((1, l))
            spans = []
            for cur_span, sum_logp in sorted(np.ndenumerate(sum_mat), key=lambda x:x[1], reverse=True):
                if cur_span[1] < cur_span[0] or cur_span[0] == l - 1 or cur_span[1] == l - 1:
                    continue
                spans.append((cur_span[0]+offset, cur_span[1]+offset, sum_logp))
                if len(spans) >= beam_size:
                    break

            return spans

        select_id_prob = sorted(enumerate(model_output["column_func"][:, 0]), key=lambda x:x[1], reverse=True)
        select = select_id_prob[0][0]
        agg = np.argmax(model_output["agg"][select, :])

        where_id_prob = sorted(enumerate(model_output["column_func"][:, 1]), key=lambda x:x[1], reverse=True)
        where_num = self._get_where_num(model_output)
        conditions = []
        for idx, wlogp in where_id_prob[:beam_size]:
            op = np.argmax(model_output["op"][idx, :])
            for span in get_span(idx):
                conditions.append((wlogp+span[2], idx, op, span[0], span[1]))
        conditions.sort(key=lambda x:x[0], reverse=True)
        return agg, select, where_num, conditions

# %%
# torch model

import torch
import os
import numpy as np
import transformers
from torch import nn

class HydraTorch(BaseModel):
    def __init__(self, config):
        self.config = config
        self.model = HydraNet(config)
        if torch.cuda.device_count() > 1:
            self.model = nn.DataParallel(self.model)
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.model.to(self.device)

        self.optimizer, self.scheduler = None, None

    def train_on_batch(self, batch):
        if self.optimizer is None:
            no_decay = ["bias", "LayerNorm.weight"]
            optimizer_grouped_parameters = [
                {
                    "params": [p for n, p in self.model.named_parameters() if not any(nd in n for nd in no_decay)],
                    "weight_decay": float(self.config["decay"]),
                },
                {"params": [p for n, p in self.model.named_parameters() if any(nd in n for nd in no_decay)],
                 "weight_decay": 0.0},
            ]
            self.optimizer = transformers.AdamW(optimizer_grouped_parameters, lr=float(self.config["learning_rate"]))
            self.scheduler = transformers.get_cosine_schedule_with_warmup(
                self.optimizer,
                num_warmup_steps=int(self.config["num_warmup_steps"]),
                num_training_steps=int(self.config["num_train_steps"]))
            self.optimizer.zero_grad()

        self.model.train()
        for k, v in batch.items():
            batch[k] = v.to(self.device)
        batch_loss = torch.mean(self.model(**batch)["loss"])
        batch_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.model.parameters(), 1.0)
        self.optimizer.step()
        self.scheduler.step()
        self.optimizer.zero_grad()

        return batch_loss.cpu().detach().numpy()

    def model_inference(self, model_inputs):
        self.model.eval()
        model_outputs = {}
        batch_size = 64 # 512
        for start_idx in range(0, model_inputs["input_ids"].shape[0], batch_size):
            input_tensor = {k: torch.from_numpy(model_inputs[k][start_idx:start_idx+batch_size]).to(self.device) for k in ["input_ids", "input_mask", "segment_ids"]}
            with torch.no_grad():
                model_output = self.model(**input_tensor)
            for k, out_tensor in model_output.items():
                if out_tensor is None:
                    continue
                if k not in model_outputs:
                    model_outputs[k] = []
                model_outputs[k].append(out_tensor.cpu().detach().numpy())

        for k in model_outputs:
            model_outputs[k] = np.concatenate(model_outputs[k], 0)

        return model_outputs

    def save(self, model_path, epoch):
        if "SAVE" in self.config and "DEBUG" not in self.config:
            save_path = os.path.join(model_path, "model_{0}.pt".format(epoch))
            if torch.cuda.device_count() > 1:
                torch.save(self.model.module.state_dict(), save_path)
            else:
                torch.save(self.model.state_dict(), save_path)
            print("Model saved in path: %s" % save_path)

    def load(self, model_path, epoch):
        pt_path = os.path.join(model_path, "model_{0}.pt".format(epoch))
        loaded_dict = torch.load(pt_path, map_location=torch.device(self.device))
        if torch.cuda.device_count() > 1:
            self.model.module.load_state_dict(loaded_dict)
        else:
            self.model.load_state_dict(loaded_dict)
        print("PyTorch model loaded from {0}".format(pt_path))

class HydraNet(nn.Module):
    def __init__(self, config):
        super(HydraNet, self).__init__()
        self.config = config
        self.base_model = create_base_model(config)
        

        # #=====Hack for RoBERTa model====
        # self.base_model.config.type_vocab_size = 2
        # single_emb = self.base_model.embeddings.token_type_embeddings
        # self.base_model.embeddings.token_type_embeddings = torch.nn.Embedding(2, single_emb.embedding_dim)
        # self.base_model.embeddings.token_type_embeddings.weight = torch.nn.Parameter(single_emb.weight.repeat([2, 1]), requires_grad=True)
        # #====================================

        drop_rate = float(config["drop_rate"]) if "drop_rate" in config else 0.0
        self.dropout = nn.Dropout(drop_rate)

        bert_hid_size = self.base_model.config.hidden_size
        projected_size = 64
        
        self.projection = nn.Linear(bert_hid_size, projected_size)
        self.column_func = nn.Linear(projected_size, 3)
        self.agg = nn.Linear(projected_size, int(config["agg_num"]))
        self.op = nn.Linear(projected_size, int(config["op_num"]))
        self.where_num = nn.Linear(projected_size, int(config["where_column_num"]) + 1)
        self.start_end = nn.Linear(projected_size, 2)

        # self.column_func = nn.Linear(bert_hid_size, 3)
        # self.agg = nn.Linear(bert_hid_size, int(config["agg_num"]))
        # self.op = nn.Linear(bert_hid_size, int(config["op_num"]))
        # self.where_num = nn.Linear(bert_hid_size, int(config["where_column_num"]) + 1)
        # self.start_end = nn.Linear(bert_hid_size, 2)

    def forward(self, input_ids, input_mask, segment_ids, agg=None, select=None, where=None, where_num=None, op=None, value_start=None, value_end=None):
        # print("[inner] input_ids size:", input_ids.size())
        if self.config["base_class"] == "roberta":
            bert_output, pooled_output = self.base_model(
                input_ids=input_ids,
                attention_mask=input_mask,
                token_type_ids=None,
                return_dict=False)
        else:
            bert_output, pooled_output = self.base_model(
                input_ids=input_ids,
                attention_mask=input_mask,
                token_type_ids=segment_ids,
                return_dict=False)
        print("pooled output before: ")
        print(pooled_output.shape)

        print("bert output before: ")
        print(bert_output.shape)

        bert_output = self.projection(bert_output)
        pooled_output = self.projection(pooled_output)
        
        print("pooled output: ")
        print(pooled_output.shape)

        print("bert output: ")
        print(bert_output.shape)

        bert_output = self.dropout(bert_output)
        pooled_output = self.dropout(pooled_output)

        column_func_logit = self.column_func(pooled_output)
        agg_logit = self.agg(pooled_output)
        op_logit = self.op(pooled_output)
        where_num_logit = self.where_num(pooled_output)
        start_end_logit = self.start_end(bert_output)
        value_span_mask = input_mask.to(dtype=bert_output.dtype)
        # value_span_mask[:, 0] = 1
        start_logit = start_end_logit[:, :, 0] * value_span_mask - 1000000.0 * (1 - value_span_mask)
        end_logit = start_end_logit[:, :, 1] * value_span_mask - 1000000.0 * (1 - value_span_mask)

        loss = None
        if select is not None:
            bceloss = nn.BCEWithLogitsLoss(reduction="none")
            cross_entropy = nn.CrossEntropyLoss(reduction="none")

            loss = cross_entropy(agg_logit, agg) * select.float()
            loss += bceloss(column_func_logit[:, 0], select.float())
            loss += bceloss(column_func_logit[:, 1], where.float())
            loss += bceloss(column_func_logit[:, 2], (1-select.float()) * (1-where.float()))
            loss += cross_entropy(where_num_logit, where_num)
            loss += cross_entropy(op_logit, op) * where.float()
            loss += cross_entropy(start_logit, value_start)
            loss += cross_entropy(end_logit, value_end)


        # return loss, column_func_logit, agg_logit, op_logit, where_num_logit, start_logit, end_logit
        log_sigmoid = nn.LogSigmoid()

        return {"column_func": log_sigmoid(column_func_logit),
                "agg": agg_logit.log_softmax(1),
                "op": op_logit.log_softmax(1),
                "where_num": where_num_logit.log_softmax(1),
                "value_start": start_logit.log_softmax(1),
                "value_end": end_logit.log_softmax(1),
                "loss": loss}

# %%
def create_model(config, is_train = False) -> BaseModel:
    if config["model_type"] == "pytorch":
        return HydraTorch(config)
    # elif config["model_type"] == "tf":
    #     return HydraTensorFlow(config, is_train, num_gpu)
    else:
        raise NotImplementedError("model type {0} is not supported".format(config["model_type"]))

# %%
# !pwd
import os
import numpy as np

class HydraEvaluator():
    def __init__(self, output_path, config, hydra_featurizer: HydraFeaturizer, model:BaseModel, note=""):
        self.config = config
        self.model = model
        self.eval_history_file = os.path.join(output_path, "eval.log")
        self.bad_case_dir = os.path.join(output_path, "bad_cases")
        os.mkdir(output_path)
        if "DEBUG" not in config:
            os.mkdir(self.bad_case_dir)
            with open(self.eval_history_file, "w", encoding="utf8") as f:
                f.write(note.rstrip() + "\n")

        self.eval_data = {}
        for eval_path in config["dev_data_path"].split("|") + config["test_data_path"].split("|"):
            eval_data = SQLDataset(eval_path, config, hydra_featurizer, True)
            self.eval_data[os.path.basename(eval_path)] = eval_data

            print("Eval Data file {0} loaded, sample num = {1}".format(eval_path, len(eval_data)))

    def _eval_imp(self, eval_data: SQLDataset, get_sq=True):
        items = ["overall", "agg", "sel", "wn", "wc", "op", "val"]
        acc = {k:0.0 for k in items}
        sq = []
        cnt = 0
        print("before_inf")
        model_outputs = self.model.dataset_inference(eval_data)
        print("after_inf")
        for input_feature, model_output in zip(eval_data.input_features, model_outputs):
            cur_acc = {k:1 for k in acc if k != "overall"}

            select_label = np.argmax(input_feature.select)
            agg_label = input_feature.agg[select_label]
            wn_label = input_feature.where_num[0]
            wc_label = [i for i, w in enumerate(input_feature.where) if w == 1]

            agg, select, where, conditions = self.model.parse_output(input_feature, model_output, wc_label)
            if agg != agg_label:
                cur_acc["agg"] = 0
            if select != select_label:
                cur_acc["sel"] = 0
            if len(where) != wn_label:
                cur_acc["wn"] = 0
            if set(where) != set(wc_label):
                cur_acc["wc"] = 0

            for w in wc_label:
                _, op, vs, ve = conditions[w]
                if op != input_feature.op[w]:
                    cur_acc["op"] = 0

                if vs != input_feature.value_start[w] or ve != input_feature.value_end[w]:
                    cur_acc["val"] = 0

            for k in cur_acc:
                acc[k] += cur_acc[k]

            all_correct = 0 if 0 in cur_acc.values() else 1
            acc["overall"] += all_correct

            if ("DEBUG" in self.config or get_sq) and not all_correct:
                try:
                    true_sq = input_feature.output_SQ()
                    pred_sq = input_feature.output_SQ(agg=agg, sel=select, conditions=[conditions[w] for w in where])
                    task_cor_text = "".join([str(cur_acc[k]) for k in items if k in cur_acc])
                    sq.append([str(cnt), input_feature.question, "|".join([task_cor_text, pred_sq, true_sq])])
                except:
                    pass
            cnt += 1

        result_str = []
        for item in items:
            result_str.append(item + ":{0:.1f}".format(acc[item] * 100.0 / cnt))

        result_str = ", ".join(result_str)

        return result_str, sq

    def eval(self, epochs):
        print(self.bad_case_dir)
        for eval_file in self.eval_data:
            result_str, sq = self._eval_imp(self.eval_data[eval_file])
            print(eval_file + ": " + result_str)

            if "DEBUG" in self.config:
                for text in sq:
                    print(text[0] + ":" + text[1] + "\t" + text[2])
            else:
                with open(self.eval_history_file, "a+", encoding="utf8") as f:
                    f.write("[{0}, epoch {1}] ".format(eval_file, epochs) + result_str + "\n")

                bad_case_file = os.path.join(self.bad_case_dir,
                                           "{0}_epoch_{1}.log".format(eval_file, epochs))
                with open(bad_case_file, "w", encoding="utf8") as f:
                    for text in sq:
                        f.write(text[0] + ":" + text[1] + "\t" + text[2] + "\n")
# Out:
# /Users/tulip/Downloads/cs626/Text2SQL/colab_data

# %%
note = ""
model_path = "model--"+datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
config["num_train_steps"] = int(num_samples * int(config["epochs"]) / int(config["batch_size"]))
step_per_epoch = num_samples / int(config["batch_size"])
print("total_steps: {0}, warm_up_steps: {1}".format(config["num_train_steps"], config["num_warmup_steps"]))

model = create_model(config, is_train=True)
evaluator = HydraEvaluator(model_path, config, featurizer, model, note)
# Out:
# total_steps: 1135, warm_up_steps: 400
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /Users/tulip/Downloads/cs626/Text2SQL/colab_data/data/wikidev.jsonl loaded. Data shapes:
# input_ids (14537, 96)
# input_mask (14537, 96)
# segment_ids (14537, 96)
# agg (14537,)
# select (14537,)
# where_num (14537,)
# where (14537,)
# op (14537,)
# value_start (14537,)
# value_end (14537,)
# Eval Data file /Users/tulip/Downloads/cs626/Text2SQL/colab_data/data/wikidev.jsonl loaded, sample num = 14537
# data/wikitest.jsonl loaded. Data shapes:
# input_ids (14431, 96)
# input_mask (14431, 96)
# segment_ids (14431, 96)
# agg (14431,)
# select (14431,)
# where_num (14431,)
# where (14431,)
# op (14431,)
# value_start (14431,)
# value_end (14431,)
# Eval Data file data/wikitest.jsonl loaded, sample num = 14431

# %%
print("start training")
print(model_path)
loss_avg, step, epoch = 0.0, 0, 0
while True:
    for batch_id, batch in enumerate(train_data_loader):
        print(batch_id)
        cur_loss = model.train_on_batch(batch)
        loss_avg = (loss_avg * step + cur_loss) / (step + 1)
        step += 1
        print("here1")
        if batch_id % 1 == 0:
            print("here2")
            currentDT = datetime.datetime.now()
            print("[{3}] epoch {0}, batch {1}, batch_loss={2:.4f}".format(epoch, batch_id, cur_loss,
                                                                            currentDT.strftime("%m-%d %H:%M:%S")))
    model.save(model_path, epoch)
    evaluator.eval(epoch)
    epoch += 1
    if epoch >= int(config["epochs"]):
        break
# Out:
# start training
# model--20221123_123520
# 0
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:36:43] epoch 0, batch 0, batch_loss=10.6696
# 1
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:36:56] epoch 0, batch 1, batch_loss=10.8315
# 2
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:37:09] epoch 0, batch 2, batch_loss=10.7581
# 3
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:37:22] epoch 0, batch 3, batch_loss=10.7151
# 4
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:37:34] epoch 0, batch 4, batch_loss=10.6158
# 5
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:37:47] epoch 0, batch 5, batch_loss=10.6292
# 6
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:38:00] epoch 0, batch 6, batch_loss=10.8070
# 7
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:38:12] epoch 0, batch 7, batch_loss=10.6437
# 8
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:38:25] epoch 0, batch 8, batch_loss=10.6912
# 9
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:38:39] epoch 0, batch 9, batch_loss=10.5173
# 10
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:38:52] epoch 0, batch 10, batch_loss=10.7471
# 11
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:39:05] epoch 0, batch 11, batch_loss=10.5807
# 12
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:39:18] epoch 0, batch 12, batch_loss=10.5495
# 13
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:39:31] epoch 0, batch 13, batch_loss=10.5314
# 14
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:39:44] epoch 0, batch 14, batch_loss=10.7152
# 15
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:39:58] epoch 0, batch 15, batch_loss=10.3949
# 16
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:40:11] epoch 0, batch 16, batch_loss=10.5171
# 17
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:40:24] epoch 0, batch 17, batch_loss=10.7078
# 18
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:40:37] epoch 0, batch 18, batch_loss=10.4927
# 19
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:40:49] epoch 0, batch 19, batch_loss=10.7969
# 20
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:41:02] epoch 0, batch 20, batch_loss=10.4613
# 21
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:41:14] epoch 0, batch 21, batch_loss=10.5273
# 22
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:41:27] epoch 0, batch 22, batch_loss=10.4138
# 23
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:41:40] epoch 0, batch 23, batch_loss=10.3679
# 24
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:41:53] epoch 0, batch 24, batch_loss=10.3568
# 25
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:42:06] epoch 0, batch 25, batch_loss=10.3649
# 26
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:42:19] epoch 0, batch 26, batch_loss=10.4337
# 27
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:42:32] epoch 0, batch 27, batch_loss=10.2345
# 28
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:42:45] epoch 0, batch 28, batch_loss=10.2884
# 29
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:43:00] epoch 0, batch 29, batch_loss=10.1473
# 30
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:43:13] epoch 0, batch 30, batch_loss=10.4025
# 31
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:43:27] epoch 0, batch 31, batch_loss=10.3020
# 32
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:43:40] epoch 0, batch 32, batch_loss=10.0769
# 33
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:43:53] epoch 0, batch 33, batch_loss=10.2344
# 34
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:44:06] epoch 0, batch 34, batch_loss=10.2045
# 35
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:44:19] epoch 0, batch 35, batch_loss=10.1600
# 36
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:44:32] epoch 0, batch 36, batch_loss=10.1848
# 37
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:44:45] epoch 0, batch 37, batch_loss=10.1331
# 38
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:44:58] epoch 0, batch 38, batch_loss=10.1123
# 39
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:45:11] epoch 0, batch 39, batch_loss=9.9415
# 40
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:45:34] epoch 0, batch 40, batch_loss=10.2776
# 41
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:45:47] epoch 0, batch 41, batch_loss=9.9761
# 42
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:46:01] epoch 0, batch 42, batch_loss=9.8978
# 43
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:46:14] epoch 0, batch 43, batch_loss=9.8054
# 44
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:46:27] epoch 0, batch 44, batch_loss=10.0776
# 45
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:46:39] epoch 0, batch 45, batch_loss=10.0464
# 46
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:46:52] epoch 0, batch 46, batch_loss=9.9705
# 47
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:47:05] epoch 0, batch 47, batch_loss=9.6086
# 48
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:47:17] epoch 0, batch 48, batch_loss=9.6747
# 49
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:47:30] epoch 0, batch 49, batch_loss=9.3931
# 50
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:47:43] epoch 0, batch 50, batch_loss=9.6125
# 51
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:47:56] epoch 0, batch 51, batch_loss=9.5609
# 52
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:48:09] epoch 0, batch 52, batch_loss=9.6256
# 53
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:48:21] epoch 0, batch 53, batch_loss=9.4342
# 54
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:48:34] epoch 0, batch 54, batch_loss=9.4086
# 55
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:48:48] epoch 0, batch 55, batch_loss=9.2750
# 56
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:49:04] epoch 0, batch 56, batch_loss=9.0549
# 57
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:49:19] epoch 0, batch 57, batch_loss=9.4215
# 58
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:49:33] epoch 0, batch 58, batch_loss=9.3116
# 59
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:49:46] epoch 0, batch 59, batch_loss=8.9532
# 60
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:49:59] epoch 0, batch 60, batch_loss=8.9123
# 61
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:50:11] epoch 0, batch 61, batch_loss=9.0666
# 62
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:50:24] epoch 0, batch 62, batch_loss=8.7324
# 63
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:50:40] epoch 0, batch 63, batch_loss=8.7241
# 64
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:50:55] epoch 0, batch 64, batch_loss=8.7369
# 65
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:51:10] epoch 0, batch 65, batch_loss=8.8316
# 66
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:51:23] epoch 0, batch 66, batch_loss=8.4228
# 67
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:51:36] epoch 0, batch 67, batch_loss=8.6508
# 68
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:51:49] epoch 0, batch 68, batch_loss=8.3583
# 69
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:52:02] epoch 0, batch 69, batch_loss=8.2022
# 70
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:52:15] epoch 0, batch 70, batch_loss=8.1429
# 71
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:52:28] epoch 0, batch 71, batch_loss=8.3322
# 72
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:52:41] epoch 0, batch 72, batch_loss=8.0935
# 73
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:52:53] epoch 0, batch 73, batch_loss=7.9390
# 74
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:53:06] epoch 0, batch 74, batch_loss=7.9478
# 75
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:53:19] epoch 0, batch 75, batch_loss=7.1340
# 76
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:53:32] epoch 0, batch 76, batch_loss=7.8429
# 77
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:53:44] epoch 0, batch 77, batch_loss=7.5916
# 78
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:53:58] epoch 0, batch 78, batch_loss=7.1301
# 79
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:54:10] epoch 0, batch 79, batch_loss=7.3020
# 80
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:54:23] epoch 0, batch 80, batch_loss=7.4109
# 81
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:54:36] epoch 0, batch 81, batch_loss=7.1630
# 82
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:54:49] epoch 0, batch 82, batch_loss=7.0584
# 83
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:55:02] epoch 0, batch 83, batch_loss=6.6598
# 84
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:55:15] epoch 0, batch 84, batch_loss=6.8383
# 85
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:55:28] epoch 0, batch 85, batch_loss=6.6946
# 86
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:55:41] epoch 0, batch 86, batch_loss=6.6744
# 87
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:55:53] epoch 0, batch 87, batch_loss=6.4252
# 88
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 12:56:06] epoch 0, batch 88, batch_loss=6.5905
# 89
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:01:01] epoch 0, batch 89, batch_loss=6.5854
# 90
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:01:18] epoch 0, batch 90, batch_loss=6.3419
# 91
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:01:34] epoch 0, batch 91, batch_loss=5.9371
# 92
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:01:53] epoch 0, batch 92, batch_loss=5.9260
# 93
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:02:07] epoch 0, batch 93, batch_loss=5.8297
# 94
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:02:20] epoch 0, batch 94, batch_loss=5.8298
# 95
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:02:33] epoch 0, batch 95, batch_loss=5.5635
# 96
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:02:47] epoch 0, batch 96, batch_loss=6.5070
# 97
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:03:01] epoch 0, batch 97, batch_loss=5.6308
# 98
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:03:15] epoch 0, batch 98, batch_loss=5.4115
# 99
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:03:29] epoch 0, batch 99, batch_loss=5.3510
# 100
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:03:43] epoch 0, batch 100, batch_loss=5.2613
# 101
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:03:56] epoch 0, batch 101, batch_loss=5.1694
# 102
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:04:10] epoch 0, batch 102, batch_loss=4.7683
# 103
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:04:23] epoch 0, batch 103, batch_loss=5.4586
# 104
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:04:36] epoch 0, batch 104, batch_loss=5.0886
# 105
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:04:48] epoch 0, batch 105, batch_loss=4.6762
# 106
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:05:01] epoch 0, batch 106, batch_loss=5.1069
# 107
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:05:14] epoch 0, batch 107, batch_loss=4.5081
# 108
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:05:27] epoch 0, batch 108, batch_loss=5.6841
# 109
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:05:40] epoch 0, batch 109, batch_loss=4.7098
# 110
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:05:53] epoch 0, batch 110, batch_loss=5.6275
# 111
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:06:06] epoch 0, batch 111, batch_loss=5.3418
# 112
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:06:20] epoch 0, batch 112, batch_loss=3.9541
# 113
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:06:40] epoch 0, batch 113, batch_loss=4.7957
# 114
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:06:59] epoch 0, batch 114, batch_loss=4.9319
# 115
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:07:14] epoch 0, batch 115, batch_loss=4.1888
# 116
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:07:33] epoch 0, batch 116, batch_loss=5.8883
# 117
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:07:49] epoch 0, batch 117, batch_loss=3.3644
# 118
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:08:04] epoch 0, batch 118, batch_loss=4.2980
# 119
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:08:20] epoch 0, batch 119, batch_loss=4.6736
# 120
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:08:36] epoch 0, batch 120, batch_loss=4.6444
# 121
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:08:54] epoch 0, batch 121, batch_loss=4.1728
# 122
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:09:09] epoch 0, batch 122, batch_loss=5.3175
# 123
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:09:29] epoch 0, batch 123, batch_loss=3.7621
# 124
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:09:43] epoch 0, batch 124, batch_loss=3.9370
# 125
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:09:57] epoch 0, batch 125, batch_loss=4.5410
# 126
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:10:12] epoch 0, batch 126, batch_loss=3.9565
# 127
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:10:26] epoch 0, batch 127, batch_loss=4.0262
# 128
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:10:40] epoch 0, batch 128, batch_loss=3.3306
# 129
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:10:54] epoch 0, batch 129, batch_loss=5.0238
# 130
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:11:09] epoch 0, batch 130, batch_loss=4.5170
# 131
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:11:23] epoch 0, batch 131, batch_loss=4.4809
# 132
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:11:37] epoch 0, batch 132, batch_loss=4.6415
# 133
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:11:51] epoch 0, batch 133, batch_loss=3.9653
# 134
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:12:05] epoch 0, batch 134, batch_loss=3.9979
# 135
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:12:19] epoch 0, batch 135, batch_loss=3.5044
# 136
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:12:34] epoch 0, batch 136, batch_loss=3.6403
# 137
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:12:48] epoch 0, batch 137, batch_loss=3.8006
# 138
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:13:01] epoch 0, batch 138, batch_loss=5.1298
# 139
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:13:14] epoch 0, batch 139, batch_loss=3.4512
# 140
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:13:27] epoch 0, batch 140, batch_loss=3.5342
# 141
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:13:41] epoch 0, batch 141, batch_loss=4.6529
# 142
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:13:54] epoch 0, batch 142, batch_loss=3.1009
# 143
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:14:09] epoch 0, batch 143, batch_loss=3.7705
# 144
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:14:24] epoch 0, batch 144, batch_loss=4.2078
# 145
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:14:39] epoch 0, batch 145, batch_loss=4.2150
# 146
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:14:54] epoch 0, batch 146, batch_loss=3.3566
# 147
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:15:08] epoch 0, batch 147, batch_loss=3.2955
# 148
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:15:24] epoch 0, batch 148, batch_loss=3.4745
# 149
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:15:38] epoch 0, batch 149, batch_loss=3.1653
# 150
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:15:53] epoch 0, batch 150, batch_loss=3.7654
# 151
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:16:11] epoch 0, batch 151, batch_loss=4.0516
# 152
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:16:27] epoch 0, batch 152, batch_loss=3.9251
# 153
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:16:43] epoch 0, batch 153, batch_loss=3.5330
# 154
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:16:58] epoch 0, batch 154, batch_loss=3.7419
# 155
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:17:13] epoch 0, batch 155, batch_loss=3.2505
# 156
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:17:27] epoch 0, batch 156, batch_loss=3.2345
# 157
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:17:43] epoch 0, batch 157, batch_loss=3.7899
# 158
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:18:03] epoch 0, batch 158, batch_loss=3.3525
# 159
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:18:22] epoch 0, batch 159, batch_loss=3.4905
# 160
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:18:37] epoch 0, batch 160, batch_loss=2.9237
# 161
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:18:50] epoch 0, batch 161, batch_loss=2.9666
# 162
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:19:05] epoch 0, batch 162, batch_loss=3.6058
# 163
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:19:19] epoch 0, batch 163, batch_loss=3.4375
# 164
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:19:32] epoch 0, batch 164, batch_loss=3.1503
# 165
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:19:44] epoch 0, batch 165, batch_loss=3.1088
# 166
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:19:57] epoch 0, batch 166, batch_loss=2.9828
# 167
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:20:10] epoch 0, batch 167, batch_loss=4.3126
# 168
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:20:22] epoch 0, batch 168, batch_loss=3.4536
# 169
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:20:35] epoch 0, batch 169, batch_loss=4.0353
# 170
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:20:47] epoch 0, batch 170, batch_loss=4.0690
# 171
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:21:00] epoch 0, batch 171, batch_loss=3.9427
# 172
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:21:12] epoch 0, batch 172, batch_loss=3.5110
# 173
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:29:26] epoch 0, batch 173, batch_loss=3.1379
# 174
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:29:41] epoch 0, batch 174, batch_loss=3.3069
# 175
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:29:56] epoch 0, batch 175, batch_loss=3.4026
# 176
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:30:09] epoch 0, batch 176, batch_loss=3.5338
# 177
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:30:22] epoch 0, batch 177, batch_loss=3.5427
# 178
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:30:35] epoch 0, batch 178, batch_loss=3.7073
# 179
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:30:48] epoch 0, batch 179, batch_loss=2.4776
# 180
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:31:03] epoch 0, batch 180, batch_loss=3.6853
# 181
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:31:20] epoch 0, batch 181, batch_loss=3.3474
# 182
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:31:35] epoch 0, batch 182, batch_loss=2.8503
# 183
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:31:50] epoch 0, batch 183, batch_loss=2.3654
# 184
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:32:07] epoch 0, batch 184, batch_loss=3.2112
# 185
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:32:22] epoch 0, batch 185, batch_loss=3.8228
# 186
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:32:38] epoch 0, batch 186, batch_loss=3.1003
# 187
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:32:52] epoch 0, batch 187, batch_loss=2.5216
# 188
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:33:07] epoch 0, batch 188, batch_loss=3.5723
# 189
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:33:22] epoch 0, batch 189, batch_loss=2.6358
# 190
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:33:37] epoch 0, batch 190, batch_loss=3.4311
# 191
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:33:53] epoch 0, batch 191, batch_loss=2.7105
# 192
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:34:08] epoch 0, batch 192, batch_loss=2.9866
# 193
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:34:24] epoch 0, batch 193, batch_loss=3.3075
# 194
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:34:39] epoch 0, batch 194, batch_loss=3.2754
# 195
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:34:55] epoch 0, batch 195, batch_loss=3.7915
# 196
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:35:10] epoch 0, batch 196, batch_loss=3.1778
# 197
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:35:25] epoch 0, batch 197, batch_loss=3.2520
# 198
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 13:35:40] epoch 0, batch 198, batch_loss=3.0369
# 199
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# ...
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:54:22] epoch 3, batch 10, batch_loss=0.7413
# 11
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:54:31] epoch 3, batch 11, batch_loss=1.4542
# 12
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:54:41] epoch 3, batch 12, batch_loss=1.0260
# 13
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:54:50] epoch 3, batch 13, batch_loss=1.0644
# 14
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:55:00] epoch 3, batch 14, batch_loss=0.9855
# 15
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:55:09] epoch 3, batch 15, batch_loss=1.3159
# 16
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:55:19] epoch 3, batch 16, batch_loss=1.0686
# 17
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:55:28] epoch 3, batch 17, batch_loss=1.4094
# 18
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:55:37] epoch 3, batch 18, batch_loss=1.4603
# 19
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:55:46] epoch 3, batch 19, batch_loss=1.0177
# 20
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:55:56] epoch 3, batch 20, batch_loss=1.2880
# 21
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:56:05] epoch 3, batch 21, batch_loss=0.6657
# 22
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:56:15] epoch 3, batch 22, batch_loss=1.3021
# 23
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:56:24] epoch 3, batch 23, batch_loss=1.3291
# 24
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:56:34] epoch 3, batch 24, batch_loss=1.1283
# 25
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:56:44] epoch 3, batch 25, batch_loss=0.9104
# 26
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:56:54] epoch 3, batch 26, batch_loss=1.3158
# 27
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:57:04] epoch 3, batch 27, batch_loss=1.6439
# 28
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:57:15] epoch 3, batch 28, batch_loss=1.1406
# 29
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:57:24] epoch 3, batch 29, batch_loss=0.8915
# 30
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:57:34] epoch 3, batch 30, batch_loss=0.9218
# 31
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:57:44] epoch 3, batch 31, batch_loss=0.6255
# 32
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:57:54] epoch 3, batch 32, batch_loss=1.4067
# 33
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:58:04] epoch 3, batch 33, batch_loss=1.3569
# 34
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:58:13] epoch 3, batch 34, batch_loss=1.0244
# 35
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:58:23] epoch 3, batch 35, batch_loss=1.1926
# 36
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:58:33] epoch 3, batch 36, batch_loss=0.6982
# 37
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:58:43] epoch 3, batch 37, batch_loss=0.6699
# 38
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:58:53] epoch 3, batch 38, batch_loss=1.0618
# 39
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:59:03] epoch 3, batch 39, batch_loss=1.0088
# 40
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:59:12] epoch 3, batch 40, batch_loss=1.1023
# 41
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:59:22] epoch 3, batch 41, batch_loss=0.9560
# 42
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:59:32] epoch 3, batch 42, batch_loss=0.8112
# 43
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:59:42] epoch 3, batch 43, batch_loss=1.1913
# 44
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 18:59:52] epoch 3, batch 44, batch_loss=0.7453
# 45
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:00:02] epoch 3, batch 45, batch_loss=0.7387
# 46
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:00:12] epoch 3, batch 46, batch_loss=0.6042
# 47
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:00:22] epoch 3, batch 47, batch_loss=0.9762
# 48
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:00:32] epoch 3, batch 48, batch_loss=1.8003
# 49
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:00:42] epoch 3, batch 49, batch_loss=1.1535
# 50
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:00:51] epoch 3, batch 50, batch_loss=1.0260
# 51
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:01:01] epoch 3, batch 51, batch_loss=1.2093
# 52
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:01:12] epoch 3, batch 52, batch_loss=1.0354
# 53
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:01:23] epoch 3, batch 53, batch_loss=0.8509
# 54
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:01:33] epoch 3, batch 54, batch_loss=1.5386
# 55
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:01:45] epoch 3, batch 55, batch_loss=0.4732
# 56
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:01:55] epoch 3, batch 56, batch_loss=1.0276
# 57
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:02:06] epoch 3, batch 57, batch_loss=0.7134
# 58
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:02:17] epoch 3, batch 58, batch_loss=1.0533
# 59
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:02:29] epoch 3, batch 59, batch_loss=0.8093
# 60
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:02:40] epoch 3, batch 60, batch_loss=1.3280
# 61
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:02:51] epoch 3, batch 61, batch_loss=0.7530
# 62
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:03:02] epoch 3, batch 62, batch_loss=1.3210
# 63
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:03:12] epoch 3, batch 63, batch_loss=0.9626
# 64
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:03:22] epoch 3, batch 64, batch_loss=1.0281
# 65
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:03:32] epoch 3, batch 65, batch_loss=0.9469
# 66
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:03:42] epoch 3, batch 66, batch_loss=0.8948
# 67
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:03:52] epoch 3, batch 67, batch_loss=1.0873
# 68
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:04:02] epoch 3, batch 68, batch_loss=0.7474
# 69
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:04:13] epoch 3, batch 69, batch_loss=0.9003
# 70
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:04:23] epoch 3, batch 70, batch_loss=1.4144
# 71
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:04:33] epoch 3, batch 71, batch_loss=1.0312
# 72
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:04:44] epoch 3, batch 72, batch_loss=0.7726
# 73
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:04:55] epoch 3, batch 73, batch_loss=0.8780
# 74
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:05:06] epoch 3, batch 74, batch_loss=0.7350
# 75
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:05:17] epoch 3, batch 75, batch_loss=1.0569
# 76
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])
# here1
# here2
# [11-23 19:05:27] epoch 3, batch 76, batch_loss=0.7286
# 77
# pooled output before:
# torch.Size([64, 768])
# bert output before:
# torch.Size([64, 96, 768])
# pooled output:
# torch.Size([64, 64])
# bert output:
# torch.Size([64, 96, 64])

# %%
model.save(model_path, epoch)
# Out:
# Model saved in path: model--20221106_184457/model_0.pt

# %%
evaluator.eval(epoch)
# Out:
# model--20221107_005826/bad_cases
# before_inf
# model prediction start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 evaluator.eval(epoch)
#
# Cell In [14], line 85, in HydraEvaluator.eval(self, epochs)
#      83 print(self.bad_case_dir)
#      84 for eval_file in self.eval_data:
# ---> 85     result_str, sq = self._eval_imp(self.eval_data[eval_file])
#      86     print(eval_file + ": " + result_str)
#      88     if "DEBUG" in self.config:
#
# Cell In [14], line 30, in HydraEvaluator._eval_imp(self, eval_data, get_sq)
#      28 cnt = 0
#      29 print("before_inf")
# ---> 30 model_outputs = self.model.dataset_inference(eval_data)
#      31 print("after_inf")
#      32 for input_feature, model_output in zip(eval_data.input_features, model_outputs):
#
# Cell In [5], line 25, in BaseModel.dataset_inference(self, dataset)
#      23 print("model prediction start")
#      24 start_time = time.time()
# ---> 25 model_outputs = self.model_inference(dataset.model_inputs)
#      27 final_outputs = []
#      28 for pos in dataset.pos:
#
# Cell In [6], line 57, in HydraTorch.model_inference(self, model_inputs)
#      55 input_tensor = {k: torch.from_numpy(model_inputs[k][start_idx:start_idx+batch_size]).to(self.device) for k in ["input_ids", "input_mask", "segment_ids"]}
#      56 with torch.no_grad():
# ---> 57     model_output = self.model(**input_tensor)
#      58 for k, out_tensor in model_output.items():
#      59     if out_tensor is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1125'>1126</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1126'>1127</a> # this function, and just call forward.
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1127'>1128</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1128'>1129</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1129'>1130</a>     return forward_call(*input, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1130'>1131</a> # Do not call functions when jit is used
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1131'>1132</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In [6], line 114, in HydraNet.forward(self, input_ids, input_mask, segment_ids, agg, select, where, where_num, op, value_start, value_end)
#     111 def forward(self, input_ids, input_mask, segment_ids, agg=None, select=None, where=None, where_num=None, op=None, value_start=None, value_end=None):
#     112     # print("[inner] input_ids size:", input_ids.size())
#     113     if self.config["base_class"] == "roberta":
# --> 114         bert_output, pooled_output = self.base_model(
#     115             input_ids=input_ids,
#     116             attention_mask=input_mask,
#     117             token_type_ids=None,
#     118             return_dict=False)
#     119     else:
#     120         bert_output, pooled_output = self.base_model(
#     121             input_ids=input_ids,
#     122             attention_mask=input_mask,
#     123             token_type_ids=segment_ids,
#     124             return_dict=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1125'>1126</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1126'>1127</a> # this function, and just call forward.
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1127'>1128</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1128'>1129</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1129'>1130</a>     return forward_call(*input, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1130'>1131</a> # Do not call functions when jit is used
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1131'>1132</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py:846, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=836'>837</a> head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=838'>839</a> embedding_output = self.embeddings(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=839'>840</a>     input_ids=input_ids,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=840'>841</a>     position_ids=position_ids,
#    (...)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=843'>844</a>     past_key_values_length=past_key_values_length,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=844'>845</a> )
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=845'>846</a> encoder_outputs = self.encoder(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=846'>847</a>     embedding_output,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=847'>848</a>     attention_mask=extended_attention_mask,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=848'>849</a>     head_mask=head_mask,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=849'>850</a>     encoder_hidden_states=encoder_hidden_states,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=850'>851</a>     encoder_attention_mask=encoder_extended_attention_mask,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=851'>852</a>     past_key_values=past_key_values,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=852'>853</a>     use_cache=use_cache,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=853'>854</a>     output_attentions=output_attentions,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=854'>855</a>     output_hidden_states=output_hidden_states,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=855'>856</a>     return_dict=return_dict,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=856'>857</a> )
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=857'>858</a> sequence_output = encoder_outputs[0]
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=858'>859</a> pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1125'>1126</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1126'>1127</a> # this function, and just call forward.
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1127'>1128</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1128'>1129</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1129'>1130</a>     return forward_call(*input, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1130'>1131</a> # Do not call functions when jit is used
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1131'>1132</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py:520, in RobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=510'>511</a>     layer_outputs = torch.utils.checkpoint.checkpoint(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=511'>512</a>         create_custom_forward(layer_module),
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=512'>513</a>         hidden_states,
#    (...)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=516'>517</a>         encoder_attention_mask,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=517'>518</a>     )
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=518'>519</a> else:
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=519'>520</a>     layer_outputs = layer_module(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=520'>521</a>         hidden_states,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=521'>522</a>         attention_mask,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=522'>523</a>         layer_head_mask,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=523'>524</a>         encoder_hidden_states,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=524'>525</a>         encoder_attention_mask,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=525'>526</a>         past_key_value,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=526'>527</a>         output_attentions,
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=527'>528</a>     )
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=529'>530</a> hidden_states = layer_outputs[0]
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=530'>531</a> if use_cache:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1125'>1126</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1126'>1127</a> # this function, and just call forward.
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1127'>1128</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1128'>1129</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1129'>1130</a>     return forward_call(*input, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1130'>1131</a> # Do not call functions when jit is used
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1131'>1132</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py:447, in RobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=443'>444</a>     cross_attn_present_key_value = cross_attention_outputs[-1]
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=444'>445</a>     present_key_value = present_key_value + cross_attn_present_key_value
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=446'>447</a> layer_output = apply_chunking_to_forward(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=447'>448</a>     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=448'>449</a> )
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=449'>450</a> outputs = (layer_output,) + outputs
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=451'>452</a> # if decoder, return the attn key/values as the last output
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/pytorch_utils.py:246, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/pytorch_utils.py?line=242'>243</a>     # concatenate output at same dimension
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/pytorch_utils.py?line=243'>244</a>     return torch.cat(output_chunks, dim=chunk_dim)
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/pytorch_utils.py?line=245'>246</a> return forward_fn(*input_tensors)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py:459, in RobertaLayer.feed_forward_chunk(self, attention_output)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=457'>458</a> def feed_forward_chunk(self, attention_output):
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=458'>459</a>     intermediate_output = self.intermediate(attention_output)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=459'>460</a>     layer_output = self.output(intermediate_output, attention_output)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=460'>461</a>     return layer_output
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1125'>1126</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1126'>1127</a> # this function, and just call forward.
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1127'>1128</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1128'>1129</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1129'>1130</a>     return forward_call(*input, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1130'>1131</a> # Do not call functions when jit is used
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1131'>1132</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py:358, in RobertaIntermediate.forward(self, hidden_states)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=355'>356</a> def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=356'>357</a>     hidden_states = self.dense(hidden_states)
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=357'>358</a>     hidden_states = self.intermediate_act_fn(hidden_states)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/roberta/modeling_roberta.py?line=358'>359</a>     return hidden_states
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1125'>1126</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1126'>1127</a> # this function, and just call forward.
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1127'>1128</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1128'>1129</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1129'>1130</a>     return forward_call(*input, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1130'>1131</a> # Do not call functions when jit is used
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/nn/modules/module.py?line=1131'>1132</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/activations.py:57, in GELUActivation.forward(self, input)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/activations.py?line=55'>56</a> def forward(self, input: Tensor) -> Tensor:
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/activations.py?line=56'>57</a>     return self.act(input)
#
# KeyboardInterrupt:
